# %%
# important library

import cv2
from matplotlib import pyplot as plt
import numpy as np

I = cv2.imread("test.png")
I = cv2.cvtColor(src = I, code = cv2.COLOR_RGB2BGR)

plt.imshow(I)
plt.show()

# %%
# Reduce the noise by Gaussian Blur
G = cv2.cvtColor(src = I, code = cv2.COLOR_BGR2GRAY)
I = cv2.GaussianBlur(G,(5,5),0)

plt.imshow(I)
plt.set_cmap('gray')

plt.show()

# %%
B = cv2.adaptiveThreshold(G, maxValue = 255,
 adaptiveMethod = cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
  thresholdType = cv2.THRESH_BINARY,
   blockSize = 25,C = 5)

plt.imshow(B)
plt.show()

# %%
low_pass = np.array([[1,4,1], [4,7,4], [1,4,1]], dtype=float) /27

L = cv2.filter2D(src = B, ddepth = -1, kernel = low_pass)

plt.imshow(L)
plt.show()

# %%
sharpen = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]], dtype = float)
S = cv2.filter2D(src = L, ddepth = -1, kernel = sharpen)


plt.imshow(S)
plt.show()

# %%
edges = cv2.Canny(G,10,200)
plt.imshow(edges, cmap='gray')
plt.show()

# %%
I = cv2.imread('test.png')
# Apply bilateral filter
bilateral = cv2.bilateralFilter(I, 15, 75, 75)

plt.imshow(cv2.cvtColor(bilateral,cv2.COLOR_BGR2RGB))
plt.show()

# %%
# Still testing
bilateral = bilateral * 0.5

K = cv2.cvtColor(S, cv2.COLOR_GRAY2BGR)
K = K * 0.5
I = cv2.add(bilateral, K)

plt.imshow(cv2.cvtColor(bilateral,cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-16-73332203c5d7> in <module>
#       1 bilateral = bilateral * 0.5
#       2
# ----> 3 K = cv2.cvtColor(S, cv2.COLOR_GRAY2BGR)
#       4 K = K * 0.5
#       5 I = cv2.add(bilateral, K)
#
# error: OpenCV(4.1.1) c:\projects\opencv-python\opencv\modules\imgproc\src\color.simd_helpers.hpp:94: error: (-2:Unspecified error) in function '__cdecl cv::impl::`anonymous-namespace'::CvtHelper<struct cv::impl::`anonymous namespace'::Set<1,-1,-1>,struct cv::impl::A0xe227985e::Set<3,4,-1>,struct cv::impl::A0xe227985e::Set<0,2,5>,2>::CvtHelper(const class cv::_InputArray &,const class cv::_OutputArray &,int)'
# > Unsupported depth of input image:
# >     'VDepth::contains(depth)'
# > where
# >     'depth' is 6 (CV_64F)
